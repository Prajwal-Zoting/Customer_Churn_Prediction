# %% [markdown]
# # Stage 02 - Data Pre-Processing

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

from matplotlib import rcParams
rcParams['figure.figsize'] = 12, 4
rcParams['lines.linewidth'] = 2
rcParams['xtick.labelsize'] = 'large'
rcParams['ytick.labelsize'] = 'large'

# %% [markdown]
# # Load Dataset

# %%
df = pd.read_excel('/content/E Commerce Dataset.xlsx', sheet_name='E Comm')
df.head()
# Out:
#    CustomerID  Churn  Tenure PreferredLoginDevice  CityTier  WarehouseToHome  \
# 0       50001      1     4.0         Mobile Phone         3              6.0
# 1       50002      1     NaN                Phone         1              8.0
# 2       50003      1     NaN                Phone         1             30.0
# 3       50004      1     0.0                Phone         3             15.0
# 4       50005      1     0.0                Phone         1             12.0
#
#   PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# 0           Debit Card  Female             3.0                         3
# 1                  UPI    Male             3.0                         4
# 2           Debit Card    Male             2.0                         4
# 3           Debit Card    Male             2.0                         4
# 4                   CC    Male             NaN                         3
#
#      PreferedOrderCat  SatisfactionScore MaritalStatus  NumberOfAddress  \
# 0  Laptop & Accessory                  2        Single                9
# 1              Mobile                  3        Single                7
# 2              Mobile                  3        Single                6
# 3  Laptop & Accessory                  5        Single                8
# 4              Mobile                  5        Single                3
#
#    Complain  OrderAmountHikeFromlastYear  CouponUsed  OrderCount  \
# 0         1                         11.0         1.0         1.0
# 1         1                         15.0         0.0         1.0
# 2         1                         14.0         0.0         1.0
# 3         0                         23.0         0.0         1.0
# 4         0                         11.0         1.0         1.0
#
#    DaySinceLastOrder  CashbackAmount
# 0                5.0          159.93
# 1                0.0          120.90
# 2                3.0          120.28
# 3                3.0          134.07
# 4                3.0          129.60

# %%
# Separate Categorical & Numerical

cats = []
nums = []

for i in df.columns:
  if df[i].dtype == 'object':
    cats.append(i)
  else:
    nums.append(i)

print('Categorical =', cats)
print('Numerical =', nums)
# Out:
# Categorical = ['PreferredLoginDevice', 'PreferredPaymentMode', 'Gender', 'PreferedOrderCat', 'MaritalStatus']
# Numerical = ['CustomerID', 'Churn', 'Tenure', 'CityTier', 'WarehouseToHome', 'HourSpendOnApp', 'NumberOfDeviceRegistered', 'SatisfactionScore', 'NumberOfAddress', 'Complain', 'OrderAmountHikeFromlastYear', 'CouponUsed', 'OrderCount', 'DaySinceLastOrder', 'CashbackAmount']

# %% [markdown]
# # Handling Missing Values

# %%
df.info()

# %%
df.isna().sum()

# %%
for i in df.columns:
    percent = round(df[i].isna().sum()*100/len(df[i]),2)
    print(f'''Column {i}:''')
    print('Missing values :',df[i].isna().sum(),'dari ',len(df))
    print(f'''Presentase missing value:''',percent, '%')
    print('---'*10)
# Out:
# Column CustomerID:
# Missing values : 0 dari  5630
# Presentase missing value: 0.0 %
# ------------------------------
# Column Churn:
# Missing values : 0 dari  5630
# Presentase missing value: 0.0 %
# ------------------------------
# Column Tenure:
# Missing values : 264 dari  5630
# Presentase missing value: 4.69 %
# ------------------------------
# Column PreferredLoginDevice:
# Missing values : 0 dari  5630
# Presentase missing value: 0.0 %
# ------------------------------
# Column CityTier:
# Missing values : 0 dari  5630
# Presentase missing value: 0.0 %
# ------------------------------
# Column WarehouseToHome:
# Missing values : 251 dari  5630
# Presentase missing value: 4.46 %
# ------------------------------
# Column PreferredPaymentMode:
# Missing values : 0 dari  5630
# Presentase missing value: 0.0 %
# ------------------------------
# Column Gender:
# Missing values : 0 dari  5630
# Presentase missing value: 0.0 %
# ------------------------------
# Column HourSpendOnApp:
# Missing values : 255 dari  5630
# Presentase missing value: 4.53 %
# ------------------------------
# Column NumberOfDeviceRegistered:
# Missing values : 0 dari  5630
# Presentase missing value: 0.0 %
# ------------------------------
# Column PreferedOrderCat:
# Missing values : 0 dari  5630
# Presentase missing value: 0.0 %
# ------------------------------
# Column SatisfactionScore:
# Missing values : 0 dari  5630
# Presentase missing value: 0.0 %
# ------------------------------
# Column MaritalStatus:
# Missing values : 0 dari  5630
# Presentase missing value: 0.0 %
# ------------------------------
# Column NumberOfAddress:
# Missing values : 0 dari  5630
# Presentase missing value: 0.0 %
# ------------------------------
# Column Complain:
# Missing values : 0 dari  5630
# Presentase missing value: 0.0 %
# ------------------------------
# Column OrderAmountHikeFromlastYear:
# Missing values : 265 dari  5630
# Presentase missing value: 4.71 %
# ------------------------------
# Column CouponUsed:
# Missing values : 256 dari  5630
# Presentase missing value: 4.55 %
# ------------------------------
# Column OrderCount:
# Missing values : 258 dari  5630
# Presentase missing value: 4.58 %
# ------------------------------
# Column DaySinceLastOrder:
# Missing values : 307 dari  5630
# Presentase missing value: 5.45 %
# ------------------------------
# Column CashbackAmount:
# Missing values : 0 dari  5630
# Presentase missing value: 0.0 %
# ------------------------------

# %%
df.describe().T
# Out:
#                               count          mean          std      min  \
# CustomerID                   5630.0  52815.500000  1625.385339  50001.0
# Churn                        5630.0      0.168384     0.374240      0.0
# Tenure                       5366.0     10.189899     8.557241      0.0
# CityTier                     5630.0      1.654707     0.915389      1.0
# WarehouseToHome              5379.0     15.639896     8.531475      5.0
# HourSpendOnApp               5375.0      2.931535     0.721926      0.0
# NumberOfDeviceRegistered     5630.0      3.688988     1.023999      1.0
# SatisfactionScore            5630.0      3.066785     1.380194      1.0
# NumberOfAddress              5630.0      4.214032     2.583586      1.0
# Complain                     5630.0      0.284902     0.451408      0.0
# OrderAmountHikeFromlastYear  5365.0     15.707922     3.675485     11.0
# CouponUsed                   5374.0      1.751023     1.894621      0.0
# OrderCount                   5372.0      3.008004     2.939680      1.0
# DaySinceLastOrder            5323.0      4.543491     3.654433      0.0
# CashbackAmount               5630.0    177.223030    49.207036      0.0
#
#                                   25%       50%         75%       max
# CustomerID                   51408.25  52815.50  54222.7500  55630.00
# Churn                            0.00      0.00      0.0000      1.00
# Tenure                           2.00      9.00     16.0000     61.00
# CityTier                         1.00      1.00      3.0000      3.00
# WarehouseToHome                  9.00     14.00     20.0000    127.00
# HourSpendOnApp                   2.00      3.00      3.0000      5.00
# NumberOfDeviceRegistered         3.00      4.00      4.0000      6.00
# SatisfactionScore                2.00      3.00      4.0000      5.00
# NumberOfAddress                  2.00      3.00      6.0000     22.00
# Complain                         0.00      0.00      1.0000      1.00
# OrderAmountHikeFromlastYear     13.00     15.00     18.0000     26.00
# CouponUsed                       1.00      1.00      2.0000     16.00
# OrderCount                       1.00      2.00      3.0000     16.00
# DaySinceLastOrder                2.00      3.00      7.0000     46.00
# CashbackAmount                 145.77    163.28    196.3925    324.99

# %%
df2 = df.copy() #Copy dataframe

# %%
#Changing Phone -> Mobile Phone to eliminate data redundancy
df2['PreferredLoginDevice'] = df2['PreferredLoginDevice'].replace({'Phone' : 'Mobile Phone'})

# %%
# Replaced CC -> Credit Card & Cash on Delivery -> COD to eliminate data redundancy
df2['PreferredPaymentMode'] = df2['PreferredPaymentMode'].replace({'CC' : 'Credit Card', 'Cash on Delivery' : 'COD'})

# %% [markdown]
# ## Imputation of data using the fillna command
# - Tenure -> median
# - WarehouseToHome -> median
# - HourSpendOnApp -> median
# - OrderAmountHikeFromlastYear -> median
# - CouponUsed -> median
# - OrderCount -> median
# - DaySinceLastOrder -> median
# > The reason for replacing the value using the median is because the mean and median values ​​are not very unequal, so the median value was chosen because it has absolute value.

# %%
df2['Tenure'].fillna(df2['Tenure'].median(), inplace=True)
df2['WarehouseToHome'].fillna(df2['WarehouseToHome'].median(), inplace=True)
df2['HourSpendOnApp'].fillna(df2['HourSpendOnApp'].median(), inplace=True)
df2['OrderAmountHikeFromlastYear'].fillna(df2['OrderAmountHikeFromlastYear'].median(), inplace=True)
df2['CouponUsed'].fillna(df2['CouponUsed'].median(), inplace=True)
df2['OrderCount'].fillna(df2['OrderCount'].median(), inplace=True)
df2['DaySinceLastOrder'].fillna(df2['DaySinceLastOrder'].median(), inplace=True)

# %%
# Check again whether data imputation has been successful
df2.isna().sum()
# Out:
# CustomerID                     0
# Churn                          0
# Tenure                         0
# PreferredLoginDevice           0
# CityTier                       0
# WarehouseToHome                0
# PreferredPaymentMode           0
# Gender                         0
# HourSpendOnApp                 0
# NumberOfDeviceRegistered       0
# PreferedOrderCat               0
# SatisfactionScore              0
# MaritalStatus                  0
# NumberOfAddress                0
# Complain                       0
# OrderAmountHikeFromlastYear    0
# CouponUsed                     0
# OrderCount                     0
# DaySinceLastOrder              0
# CashbackAmount                 0
# dtype: int64

# %%
# View the value count of numerical variables
for col in nums:
    percent = round(df2[col].value_counts()*100/len(df2[col]),2)
    print(f'''Value count kolom {col}:''')
    print(df2[col].value_counts())
    print('')
    print('Presentase :\n',percent)
    print('---'*10)
    print()
# Out:
# Value count kolom CustomerID:
# 50001    1
# 53751    1
# 53759    1
# 53758    1
# 53757    1
#         ..
# 51876    1
# 51875    1
# 51874    1
# 51873    1
# 55630    1
# Name: CustomerID, Length: 5630, dtype: int64
#
# Presentase :
#  50001    0.02
# 53751    0.02
# 53759    0.02
# 53758    0.02
# 53757    0.02
#          ...
# 51876    0.02
# 51875    0.02
# 51874    0.02
# 51873    0.02
# 55630    0.02
# Name: CustomerID, Length: 5630, dtype: float64
# ------------------------------
#
# Value count kolom Churn:
# 0    4682
# 1     948
# Name: Churn, dtype: int64
#
# Presentase :
#  0    83.16
# 1    16.84
# Name: Churn, dtype: float64
# ------------------------------
#
# Value count kolom Tenure:
# 1.0     690
# 9.0     511
# 0.0     508
# 8.0     263
# 7.0     221
# 10.0    213
# 5.0     204
# 4.0     203
# 3.0     195
# 11.0    194
# 6.0     183
# 12.0    182
# 13.0    181
# 14.0    176
# 2.0     167
# 15.0    159
# 16.0    149
# 19.0    140
# 18.0    123
# 20.0    109
# 17.0    106
# 23.0     89
# 21.0     84
# 22.0     76
# 24.0     75
# 28.0     70
# 30.0     66
# 27.0     66
# 26.0     60
# 25.0     59
# 29.0     55
# 31.0     49
# 50.0      1
# 60.0      1
# 51.0      1
# 61.0      1
# Name: Tenure, dtype: int64
#
# Presentase :
#  1.0     12.26
# 9.0      9.08
# 0.0      9.02
# 8.0      4.67
# 7.0      3.93
# 10.0     3.78
# 5.0      3.62
# 4.0      3.61
# 3.0      3.46
# 11.0     3.45
# 6.0      3.25
# 12.0     3.23
# 13.0     3.21
# 14.0     3.13
# 2.0      2.97
# 15.0     2.82
# 16.0     2.65
# 19.0     2.49
# 18.0     2.18
# 20.0     1.94
# 17.0     1.88
# 23.0     1.58
# 21.0     1.49
# 22.0     1.35
# 24.0     1.33
# 28.0     1.24
# 30.0     1.17
# 27.0     1.17
# 26.0     1.07
# 25.0     1.05
# 29.0     0.98
# 31.0     0.87
# 50.0     0.02
# 60.0     0.02
# 51.0     0.02
# 61.0     0.02
# Name: Tenure, dtype: float64
# ------------------------------
#
# Value count kolom CityTier:
# 1    3666
# 3    1722
# 2     242
# Name: CityTier, dtype: int64
#
# Presentase :
#  1    65.12
# 3    30.59
# 2     4.30
# Name: CityTier, dtype: float64
# ------------------------------
#
# Value count kolom WarehouseToHome:
# 9.0      559
# 14.0     550
# 8.0      444
# 7.0      389
# 16.0     322
# 6.0      295
# 15.0     288
# 10.0     274
# 13.0     249
# 11.0     233
# 12.0     221
# 17.0     217
# 22.0     104
# 31.0     101
# 23.0      96
# 30.0      94
# 32.0      94
# 35.0      93
# 18.0      89
# 26.0      89
# 25.0      86
# 21.0      85
# 24.0      85
# 27.0      81
# 29.0      81
# 19.0      75
# 20.0      74
# 28.0      71
# 33.0      67
# 34.0      63
# 36.0      51
# 5.0        8
# 126.0      1
# 127.0      1
# Name: WarehouseToHome, dtype: int64
#
# Presentase :
#  9.0      9.93
# 14.0     9.77
# 8.0      7.89
# 7.0      6.91
# 16.0     5.72
# 6.0      5.24
# 15.0     5.12
# 10.0     4.87
# 13.0     4.42
# 11.0     4.14
# 12.0     3.93
# 17.0     3.85
# 22.0     1.85
# 31.0     1.79
# 23.0     1.71
# 30.0     1.67
# 32.0     1.67
# 35.0     1.65
# 18.0     1.58
# 26.0     1.58
# 25.0     1.53
# 21.0     1.51
# 24.0     1.51
# 27.0     1.44
# 29.0     1.44
# 19.0     1.33
# 20.0     1.31
# 28.0     1.26
# 33.0     1.19
# 34.0     1.12
# 36.0     0.91
# 5.0      0.14
# 126.0    0.02
# 127.0    0.02
# Name: WarehouseToHome, dtype: float64
# ------------------------------
#
# Value count kolom HourSpendOnApp:
# 3.0    2942
# 2.0    1471
# 4.0    1176
# 1.0      35
# 0.0       3
# 5.0       3
# Name: HourSpendOnApp, dtype: int64
#
# Presentase :
#  3.0    52.26
# 2.0    26.13
# 4.0    20.89
# 1.0     0.62
# 0.0     0.05
# 5.0     0.05
# Name: HourSpendOnApp, dtype: float64
# ------------------------------
#
# Value count kolom NumberOfDeviceRegistered:
# 4    2377
# 3    1699
# 5     881
# 2     276
# 1     235
# 6     162
# Name: NumberOfDeviceRegistered, dtype: int64
#
# Presentase :
#  4    42.22
# 3    30.18
# 5    15.65
# 2     4.90
# 1     4.17
# 6     2.88
# Name: NumberOfDeviceRegistered, dtype: float64
# ------------------------------
#
# Value count kolom SatisfactionScore:
# 3    1698
# 1    1164
# 5    1108
# 4    1074
# 2     586
# Name: SatisfactionScore, dtype: int64
#
# Presentase :
#  3    30.16
# 1    20.67
# 5    19.68
# 4    19.08
# 2    10.41
# Name: SatisfactionScore, dtype: float64
# ------------------------------
#
# Value count kolom NumberOfAddress:
# 2     1369
# 3     1278
# 4      588
# 5      571
# 6      382
# 1      371
# 8      280
# 7      256
# 9      239
# 10     194
# 11      98
# 19       1
# 21       1
# 20       1
# 22       1
# Name: NumberOfAddress, dtype: int64
#
# Presentase :
#  2     24.32
# 3     22.70
# 4     10.44
# 5     10.14
# 6      6.79
# 1      6.59
# 8      4.97
# 7      4.55
# 9      4.25
# 10     3.45
# 11     1.74
# 19     0.02
# 21     0.02
# 20     0.02
# 22     0.02
# Name: NumberOfAddress, dtype: float64
# ------------------------------
#
# Value count kolom Complain:
# 0    4026
# 1    1604
# Name: Complain, dtype: int64
#
# Presentase :
#  0    71.51
# 1    28.49
# Name: Complain, dtype: float64
# ------------------------------
#
# Value count kolom OrderAmountHikeFromlastYear:
# 15.0    807
# 14.0    750
# 13.0    741
# 12.0    728
# 11.0    391
# 16.0    333
# 18.0    321
# 19.0    311
# 17.0    297
# 20.0    243
# 21.0    190
# 22.0    184
# 23.0    144
# 24.0     84
# 25.0     73
# 26.0     33
# Name: OrderAmountHikeFromlastYear, dtype: int64
#
# Presentase :
#  15.0    14.33
# 14.0    13.32
# 13.0    13.16
# 12.0    12.93
# 11.0     6.94
# 16.0     5.91
# 18.0     5.70
# 19.0     5.52
# 17.0     5.28
# 20.0     4.32
# 21.0     3.37
# 22.0     3.27
# 23.0     2.56
# 24.0     1.49
# 25.0     1.30
# 26.0     0.59
# Name: OrderAmountHikeFromlastYear, dtype: float64
# ------------------------------
#
# Value count kolom CouponUsed:
# 1.0     2361
# 2.0     1283
# 0.0     1030
# 3.0      327
# 4.0      197
# 5.0      129
# 6.0      108
# 7.0       89
# 8.0       42
# 10.0      14
# 9.0       13
# 11.0      12
# 12.0       9
# 13.0       8
# 14.0       5
# 16.0       2
# 15.0       1
# Name: CouponUsed, dtype: int64
#
# Presentase :
#  1.0     41.94
# 2.0     22.79
# 0.0     18.29
# 3.0      5.81
# 4.0      3.50
# 5.0      2.29
# 6.0      1.92
# 7.0      1.58
# 8.0      0.75
# 10.0     0.25
# 9.0      0.23
# 11.0     0.21
# 12.0     0.16
# 13.0     0.14
# 14.0     0.09
# 16.0     0.04
# 15.0     0.02
# Name: CouponUsed, dtype: float64
# ------------------------------
#
# Value count kolom OrderCount:
# 2.0     2283
# 1.0     1751
# 3.0      371
# 7.0      206
# 4.0      204
# 5.0      181
# 8.0      172
# 6.0      137
# 9.0       62
# 12.0      54
# 11.0      51
# 10.0      36
# 14.0      36
# 15.0      33
# 13.0      30
# 16.0      23
# Name: OrderCount, dtype: int64
#
# Presentase :
#  2.0     40.55
# 1.0     31.10
# 3.0      6.59
# 7.0      3.66
# 4.0      3.62
# 5.0      3.21
# 8.0      3.06
# 6.0      2.43
# 9.0      1.10
# 12.0     0.96
# 11.0     0.91
# 10.0     0.64
# 14.0     0.64
# 15.0     0.59
# 13.0     0.53
# 16.0     0.41
# Name: OrderCount, dtype: float64
# ------------------------------
#
# Value count kolom DaySinceLastOrder:
# 3.0     1207
# 2.0      792
# 1.0      614
# 8.0      538
# 0.0      496
# 7.0      447
# 4.0      431
# 9.0      299
# 5.0      228
# 10.0     157
# 6.0      113
# 11.0      91
# 12.0      69
# 13.0      51
# 14.0      35
# 15.0      19
# 17.0      17
# 16.0      13
# 18.0      10
# 30.0       1
# 46.0       1
# 31.0       1
# Name: DaySinceLastOrder, dtype: int64
#
# Presentase :
#  3.0     21.44
# 2.0     14.07
# 1.0     10.91
# 8.0      9.56
# 0.0      8.81
# 7.0      7.94
# 4.0      7.66
# 9.0      5.31
# 5.0      4.05
# 10.0     2.79
# 6.0      2.01
# 11.0     1.62
# 12.0     1.23
# 13.0     0.91
# 14.0     0.62
# 15.0     0.34
# 17.0     0.30
# 16.0     0.23
# 18.0     0.18
# 30.0     0.02
# 46.0     0.02
# 31.0     0.02
# Name: DaySinceLastOrder, dtype: float64
# ------------------------------
#
# Value count kolom CashbackAmount:
# 123.42    8
# 149.36    8
# 148.42    8
# 188.47    7
# 154.73    7
#          ..
# 174.84    1
# 127.74    1
# 145.05    1
# 174.28    1
# 173.78    1
# Name: CashbackAmount, Length: 2586, dtype: int64
#
# Presentase :
#  123.42    0.14
# 149.36    0.14
# 148.42    0.14
# 188.47    0.12
# 154.73    0.12
#           ...
# 174.84    0.02
# 127.74    0.02
# 145.05    0.02
# 174.28    0.02
# 173.78    0.02
# Name: CashbackAmount, Length: 2586, dtype: float64
# ------------------------------

# %%
# View the count value of categorical variables
for col in cats:
    percent = round(df2[col].value_counts()*100/len(df2[col]),2)
    print(f'''Value count kolom {col}:''')
    print(df2[col].value_counts())
    print('')
    print('Presentase :\n',percent)
    print('---'*10)
    print()
# Out:
# Value count kolom PreferredLoginDevice:
# Mobile Phone    3996
# Computer        1634
# Name: PreferredLoginDevice, dtype: int64
#
# Presentase :
#  Mobile Phone    70.98
# Computer        29.02
# Name: PreferredLoginDevice, dtype: float64
# ------------------------------
#
# Value count kolom PreferredPaymentMode:
# Debit Card     2314
# Credit Card    1774
# E wallet        614
# COD             514
# UPI             414
# Name: PreferredPaymentMode, dtype: int64
#
# Presentase :
#  Debit Card     41.10
# Credit Card    31.51
# E wallet       10.91
# COD             9.13
# UPI             7.35
# Name: PreferredPaymentMode, dtype: float64
# ------------------------------
#
# Value count kolom Gender:
# Male      3384
# Female    2246
# Name: Gender, dtype: int64
#
# Presentase :
#  Male      60.11
# Female    39.89
# Name: Gender, dtype: float64
# ------------------------------
#
# Value count kolom PreferedOrderCat:
# Laptop & Accessory    2050
# Mobile Phone          1271
# Fashion                826
# Mobile                 809
# Grocery                410
# Others                 264
# Name: PreferedOrderCat, dtype: int64
#
# Presentase :
#  Laptop & Accessory    36.41
# Mobile Phone          22.58
# Fashion               14.67
# Mobile                14.37
# Grocery                7.28
# Others                 4.69
# Name: PreferedOrderCat, dtype: float64
# ------------------------------
#
# Value count kolom MaritalStatus:
# Married     2986
# Single      1796
# Divorced     848
# Name: MaritalStatus, dtype: int64
#
# Presentase :
#  Married     53.04
# Single      31.90
# Divorced    15.06
# Name: MaritalStatus, dtype: float64
# ------------------------------

# %% [markdown]
# # Statistical Summary

# %% [markdown]
# ## Statistical analysis after data imputation
# - Univariate Analysis (Boxplot) after data imputation
# - Multivariate Analysis (Pairplot KDE) after data imputation
# - Multivariate Analysis (Heatmap) after data imputation
# > Perform data visualization after carrying out the data imputation process for handling missing values ​​to compare with the data visualization in the previous stage and also to look for data that needs further treatment.

# %% [markdown]
# ### Univariate Analysis

# %%
# Create a boxplot diagram
plt.figure(figsize=(18,4))

for i in range (0, len(nums)):
    plt.subplot(1, len(nums), i+1)
    sns.boxplot(y=df2[nums[i]], color='cyan', orient='v')
    plt.tight_layout(pad = 2)

# %% [markdown]
# ### Multivariate Analysis

# %%
# Pair Plots (Numeric)
sns.pairplot(df2, diag_kind='kde', hue='Churn')

# %%
# Correlation Heatmap (Numeric)
plt.figure(figsize=(8,8))
sns.heatmap(df2.corr(), cmap='Blues', annot=True, fmt='.2f')
# Out:
# <Axes: >

# %% [markdown]
# # Handling Duplicated Data

# %%
df2.head()

# %%
df2.duplicated().sum()
# Out:
# 0

# %% [markdown]
# tidak ada data duplikasi

# %% [markdown]
# # Outlier

# %%
from scipy import stats

# %%
print(f'Number of rows before filtering outliers : {len(df2)}')

filtered_entries = np.array ([True] * len(df2))

for col in ['Tenure', 'WarehouseToHome', 'CouponUsed', 'DaySinceLastOrder', 'CashbackAmount']:
  zscore = abs(stats.zscore(df[col]))
  filtered_entries = (zscore < 3)

df2 = df2[filtered_entries]
print(f'Number of rows after filtering outliers : {len(df2)}')
# Out:
# Number of rows before filtering outliers : 5630
# Number of rows after filtering outliers : 5619

# %% [markdown]
# # Feature Encoding

# %%
mapping_gender = {
    'Female' : 0,
    'Male' : 1
}
df2['Gender'] = df2['Gender'].map(mapping_gender)

# %%
for cat in ['PreferredLoginDevice','PreferredPaymentMode','PreferedOrderCat','MaritalStatus']:
  onehots = pd.get_dummies(df2[cat], prefix=cat)
  df2 = df2.join(onehots)

# %%
# drop the original category column (because it has been encoded)
df2 = df2.drop(columns=['PreferredLoginDevice','PreferredPaymentMode','PreferedOrderCat','MaritalStatus']).copy()

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5619 entries, 0 to 5629
# Data columns (total 32 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   CustomerID                           5619 non-null   int64
#  1   Churn                                5619 non-null   int64
#  2   Tenure                               5619 non-null   float64
#  3   CityTier                             5619 non-null   int64
#  4   WarehouseToHome                      5619 non-null   float64
#  5   Gender                               5619 non-null   int64
#  6   HourSpendOnApp                       5619 non-null   float64
#  7   NumberOfDeviceRegistered             5619 non-null   int64
#  8   SatisfactionScore                    5619 non-null   int64
#  9   NumberOfAddress                      5619 non-null   int64
#  10  Complain                             5619 non-null   int64
#  11  OrderAmountHikeFromlastYear          5619 non-null   float64
#  12  CouponUsed                           5619 non-null   float64
#  13  OrderCount                           5619 non-null   float64
#  14  DaySinceLastOrder                    5619 non-null   float64
#  15  CashbackAmount                       5619 non-null   float64
#  16  PreferredLoginDevice_Computer        5619 non-null   uint8
#  17  PreferredLoginDevice_Mobile Phone    5619 non-null   uint8
#  18  PreferredPaymentMode_COD             5619 non-null   uint8
#  19  PreferredPaymentMode_Credit Card     5619 non-null   uint8
#  20  PreferredPaymentMode_Debit Card      5619 non-null   uint8
#  21  PreferredPaymentMode_E wallet        5619 non-null   uint8
#  22  PreferredPaymentMode_UPI             5619 non-null   uint8
#  23  PreferedOrderCat_Fashion             5619 non-null   uint8
#  24  PreferedOrderCat_Grocery             5619 non-null   uint8
#  25  PreferedOrderCat_Laptop & Accessory  5619 non-null   uint8
#  26  PreferedOrderCat_Mobile              5619 non-null   uint8
#  27  PreferedOrderCat_Mobile Phone        5619 non-null   uint8
#  28  PreferedOrderCat_Others              5619 non-null   uint8
#  29  MaritalStatus_Divorced               5619 non-null   uint8
#  30  MaritalStatus_Married                5619 non-null   uint8
#  31  MaritalStatus_Single                 5619 non-null   uint8
# dtypes: float64(8), int64(8), uint8(16)
# memory usage: 963.1 KB

# %%
df2.head()
# Out:
#    CustomerID  Churn  Tenure  CityTier  WarehouseToHome  Gender  \
# 0       50001      1     4.0         3              6.0       0
# 1       50002      1     9.0         1              8.0       1
# 2       50003      1     9.0         1             30.0       1
# 3       50004      1     0.0         3             15.0       1
# 4       50005      1     0.0         1             12.0       1
#
#    HourSpendOnApp  NumberOfDeviceRegistered  SatisfactionScore  \
# 0             3.0                         3                  2
# 1             3.0                         4                  3
# 2             2.0                         4                  3
# 3             2.0                         4                  5
# 4             3.0                         3                  5
#
#    NumberOfAddress  ...  PreferredPaymentMode_UPI  PreferedOrderCat_Fashion  \
# 0                9  ...                         0                         0
# 1                7  ...                         1                         0
# 2                6  ...                         0                         0
# 3                8  ...                         0                         0
# 4                3  ...                         0                         0
#
#    PreferedOrderCat_Grocery  PreferedOrderCat_Laptop & Accessory  \
# 0                         0                                    1
# 1                         0                                    0
# 2                         0                                    0
# 3                         0                                    1
# 4                         0                                    0
#
#    PreferedOrderCat_Mobile  PreferedOrderCat_Mobile Phone  \
# 0                        0                              0
# 1                        1                              0
# 2                        1                              0
# 3                        0                              0
# 4                        1                              0
#
#    PreferedOrderCat_Others  MaritalStatus_Divorced  MaritalStatus_Married  \
# 0                        0                       0                      0
# 1                        0                       0                      0
# 2                        0                       0                      0
# 3                        0                       0                      0
# 4                        0                       0                      0
#
#    MaritalStatus_Single
# 0                     1
# 1                     1
# 2                     1
# 3                     1
# 4                     1
#
# [5 rows x 32 columns]

# %% [markdown]
# # Feature Transformation

# %%
from scipy.stats import skew, kurtosis

# %%
feature_trans = nums.copy()
del feature_trans[:2]
feature_normal = []
feature_non_normal = []

for i in feature_trans:
  skw = skew(df2[i])
  kts = kurtosis(df2[i])
  if skw < 2 and skw > -2:
    if kts < 2 and kts > -2:
      feature_normal.append(i)
    else:
      feature_non_normal.append(i)
  else:
    feature_non_normal.append(i)

print('Distribution Normal:', feature_normal)
print('Distribution Non Normal:', feature_non_normal)
# Out:
# Distribution Normal: ['Tenure', 'CityTier', 'HourSpendOnApp', 'NumberOfDeviceRegistered', 'SatisfactionScore', 'NumberOfAddress', 'Complain', 'OrderAmountHikeFromlastYear', 'CashbackAmount']
# Distribution Non Normal: ['WarehouseToHome', 'CouponUsed', 'OrderCount', 'DaySinceLastOrder']

# %%
from sklearn.model_selection import train_test_split

# %%
feature = df2.columns.tolist()
del feature[:2]
feature

# %%
transform = feature_normal + feature_non_normal
X = df2[feature]
y = df2['Churn']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=3)

# %%
from sklearn.preprocessing import StandardScaler

# %%
for i in transform:
  scaler = StandardScaler().fit(X_train[[i]])
  X_train[i] = scaler.transform(X_train[[i]])
  X_test[i] = scaler.transform(X_test[[i]])

X_train.head()
# Out:
#         Tenure  CityTier  WarehouseToHome  Gender  HourSpendOnApp  \
# 3924  1.306801  1.500520        -0.779734       1        0.084913
# 2198 -1.209991 -0.701138        -0.191320       1       -1.324215
# 5349 -0.371060  1.500520        -0.779734       1        1.494042
# 1337  0.228176  1.500520         1.691603       0       -1.324215
# 1486  0.947259 -0.701138         2.280017       1       -1.324215
#
#       NumberOfDeviceRegistered  SatisfactionScore  NumberOfAddress  Complain  \
# 3924                  0.306939           0.668818         1.862855 -0.622729
# 2198                 -0.668175           1.389097        -0.845974 -0.622729
# 5349                  0.306939          -1.492020        -0.458998 -0.622729
# 1337                  0.306939          -1.492020        -1.232950 -0.622729
# 1486                 -0.668175          -1.492020         0.701928 -0.622729
#
#       OrderAmountHikeFromlastYear  ...  PreferredPaymentMode_UPI  \
# 3924                    -1.018592  ...                         0
# 2198                     2.584036  ...                         0
# 5349                    -0.187216  ...                         0
# 1337                    -1.295717  ...                         0
# 1486                    -0.741467  ...                         0
#
#       PreferedOrderCat_Fashion  PreferedOrderCat_Grocery  \
# 3924                         0                         0
# 2198                         0                         0
# 5349                         0                         0
# 1337                         0                         1
# 1486                         0                         0
#
#       PreferedOrderCat_Laptop & Accessory  PreferedOrderCat_Mobile  \
# 3924                                    1                        0
# 2198                                    0                        1
# 5349                                    1                        0
# 1337                                    0                        0
# 1486                                    0                        1
#
#       PreferedOrderCat_Mobile Phone  PreferedOrderCat_Others  \
# 3924                              0                        0
# 2198                              0                        0
# 5349                              0                        0
# 1337                              0                        0
# 1486                              0                        0
#
#       MaritalStatus_Divorced  MaritalStatus_Married  MaritalStatus_Single
# 3924                       0                      1                     0
# 2198                       0                      0                     1
# 5349                       0                      1                     0
# 1337                       0                      1                     0
# 1486                       0                      0                     1
#
# [5 rows x 30 columns]

# %%
df2.describe()
# Out:
#          CustomerID        Churn       Tenure     CityTier  WarehouseToHome  \
# count   5619.000000  5619.000000  5619.000000  5619.000000      5619.000000
# mean   52816.221392     0.168713    10.125467     1.653853        15.563623
# std     1625.642617     0.374532     8.350080     0.915021         8.342056
# min    50001.000000     0.000000     0.000000     1.000000         5.000000
# 25%    51410.500000     0.000000     3.000000     1.000000         9.000000
# 50%    52815.000000     0.000000     9.000000     1.000000        14.000000
# 75%    54224.500000     0.000000    15.000000     3.000000        20.000000
# max    55630.000000     1.000000    61.000000     3.000000       127.000000
#
#             Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# count  5619.000000     5619.000000               5619.000000
# mean      0.600819        2.934508                  3.688201
# std       0.489774        0.705456                  1.023898
# min       0.000000        0.000000                  1.000000
# 25%       0.000000        2.000000                  3.000000
# 50%       1.000000        3.000000                  4.000000
# 75%       1.000000        3.000000                  4.000000
# max       1.000000        5.000000                  6.000000
#
#        SatisfactionScore  NumberOfAddress  ...  PreferredPaymentMode_UPI  \
# count        5619.000000      5619.000000  ...               5619.000000
# mean            3.065848         4.216409  ...                  0.073679
# std             1.380046         2.584108  ...                  0.261270
# min             1.000000         1.000000  ...                  0.000000
# 25%             2.000000         2.000000  ...                  0.000000
# 50%             3.000000         3.000000  ...                  0.000000
# 75%             4.000000         6.000000  ...                  0.000000
# max             5.000000        22.000000  ...                  1.000000
#
#        PreferedOrderCat_Fashion  PreferedOrderCat_Grocery  \
# count               5619.000000               5619.000000
# mean                   0.147001                  0.072611
# std                    0.354139                  0.259520
# min                    0.000000                  0.000000
# 25%                    0.000000                  0.000000
# 50%                    0.000000                  0.000000
# 75%                    0.000000                  0.000000
# max                    1.000000                  1.000000
#
#        PreferedOrderCat_Laptop & Accessory  PreferedOrderCat_Mobile  \
# count                          5619.000000              5619.000000
# mean                              0.363944                 0.143976
# std                               0.481176                 0.351096
# min                               0.000000                 0.000000
# 25%                               0.000000                 0.000000
# 50%                               0.000000                 0.000000
# 75%                               1.000000                 0.000000
# max                               1.000000                 1.000000
#
#        PreferedOrderCat_Mobile Phone  PreferedOrderCat_Others  \
# count                    5619.000000              5619.000000
# mean                        0.225841                 0.046628
# std                         0.418172                 0.210858
# min                         0.000000                 0.000000
# 25%                         0.000000                 0.000000
# 50%                         0.000000                 0.000000
# 75%                         0.000000                 0.000000
# max                         1.000000                 1.000000
#
#        MaritalStatus_Divorced  MaritalStatus_Married  MaritalStatus_Single
# count             5619.000000            5619.000000           5619.000000
# mean                 0.150739               0.529632              0.319630
# std                  0.357826               0.499166              0.466375
# min                  0.000000               0.000000              0.000000
# 25%                  0.000000               0.000000              0.000000
# 50%                  0.000000               1.000000              0.000000
# 75%                  0.000000               1.000000              1.000000
# max                  1.000000               1.000000              1.000000
#
# [8 rows x 32 columns]

# %% [markdown]
# # Class Imbalance

# %% [markdown]
# Karena target klasifikasi pada pemodelan yang akan dilakukan menggunakan kolom churn, maka perlu dicek dahulu apakah kolom churn memiliki data yang imbalanced atau balanced.

# %%
df2['Churn_Class'] = df2['Churn']>0.9
print(df2['Churn_Class'].value_counts())
#Displays the number of churned and non-churn customers, creating categorical type targets
# Out:
# False    4671
# True      948
# Name: Churn_Class, dtype: int64

# %%
x = df2[[col for col in df2.columns if col not in ['Churn_Class','Churn']]].values
y = df2['Churn_Class'].values
print(x.shape)
print(y.shape)
#Separation of features and targets
# Out:
# (5619, 31)
# (5619,)
